# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfDoeg/Colegio_Invisible/blob/master/01_cuaderno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Colegio Invisible
# <center>
# <div>
# <img src="https://github.com/ProfDoeg/Colegio_Invisible/raw/main/img/colegio_invisible.jpeg" width="250"/>
# </div>
# </center>
#
#
# ---
# ***
# The Invisible College was a small community of interacting Enlightenment scholars who often met face-to-face, exchanged ideas and encouraged each other. One group that has been described as a precursor group to the Royal Society of London. The concept of "invisible college" is mentioned in German Rosicrucian pamphlets in the early 17th century.
# ***
# El Colegio Invisible era una pequeña comunidad de eruditos de la Ilustración que interactuaban y que a menudo se encontraban cara a cara, intercambiaban ideas y se animaban mutuamente. Un grupo que ha sido descrito como un grupo precursor de la Royal Society of London. El concepto de "universidad invisible" se menciona en los folletos rosacruces alemanes a principios del siglo XVII.
# ***
# ---

# %% [markdown]
# # Preparando El Espacio
#
#
# ---
# ***
# Because we are working in the Google Cloud there are none of the files available from the original Github repository. In order to access those files we will clone the git repository into the cloud, access the files we need, and delete the repository.
# ***
# Debido a que estamos trabajando en Google Cloud, no hay ninguno de los archivos disponibles en el repositorio original de Github. Para acceder a esos archivos, clonaremos el repositorio de git en la nube, accederemos a los archivos que necesitamos y eliminaremos el repositorio.
# ***
# ---

# %%
! ls

# %%
# !ls
! git clone https://github.com/ProfDoeg/Colegio_Invisible.git
! unzip Colegio_Invisible/img.zip
! rm -r Colegio_Invisible
# !ls

# %%
! ls img

# %% [markdown]
# # Mirando el Espacio
#
# ---
# ***
# Now that we have local files we can access them from Python as follows:
# ***
# Ahora que tenemos archivos locales, podemos acceder a ellos desde Python de la siguiente manera:
# ***
# ---

# %%
from PIL import Image
import time
imgs = [('xmas','jpeg',20), 
        ('cry','jpeg',15),('rough','png',10),
        ('drop','jpeg',15), ('house','jpeg',15), ('hide','jpeg',15) ]

# %%
from IPython.display import Image 

for name,ext,dt in imgs:
    path = f'img/hg_{name}.{ext}'
    show=Image(path)
    display(show)
    time.sleep(dt/5)

# %% [markdown]
# # Metas (Goals)
#
# ---
# ***
# By the end of this Introduction to Python you should understand:
# ***
# Al final de esta Introducción a Python, debería comprender:
# ***
# ---
# - Lanzamiento de un cuaderno CoLab desde Github (Launching a CoLab Notebook from Github)
# - Comprensión de la estructura de un cuaderno CoLab (Understanding the Structure of a CoLab Notebook)
# - Guardar el cuaderno (Saving the Notebook)
# - Guardar otros archivos (Saving Other Files)
# - Carga de otros archivos (Uploading Other Files)
# - Comandos básicos de la terminal (Basic Terminal Commands)
# - Instalación e importación de bibliotecas (Installing and Importing Libraries)
# - Tener curiosidad por las cripto (Getting Curious About Crypto)

# %% [markdown]
# # Lazamiento CoLab desde Github (Launching a CoLab Notebook from Github)
#
# ---
# ***
# Launching the Jupyter notebook from Github is easy. We can simply click on the supplied banner.
# ***
# Lanzar el cuaderno Jupyter desde Github es fácil. Simplemente podemos hacer clic en el banner suministrado.
# ***
# ---
# <a href="https://colab.research.google.com/github/ProfDoeg/Colegio_Invisible/blob/master/01_cuaderno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Comprensión de la estructura de un cuaderno CoLab (Understanding the Structure of a CoLab Notebook)
#
#
# ---
# ***
# There are two kinds of cells in a notebook:
# ***
# Hay dos tipos de celdas en un cuaderno:
# ***
# ---
#
# - `+ Code` esto es para **Python** y comandos de **Terminal**
# - `+ Text` esto es para **Markdown**
#
# Este celda es **Markdown**

# %%
# este celda es Python
print('Hola Python')
# Out:
# Hola Python

# %% [markdown]
# Uns celda de `Code` con un signo de exclamación `!` al principio es con un signo de exclamación! al principio es para comandos de **Terminal**

# %%
! ls
# Out:
# drive  sample_data

# %% [markdown]
# # Guardar el cuaderno (Saving the Notebook)
#
# ---
# ***
# Save the notebook by clicking the pulldown `File` and selecting the appropriate method:
# ***
# Guarde el cuaderno haciendo clic en el menú desplegable `Archivo` y seleccionando el método apropiado:
# ***
# ---
# - Guardar una copia en Drive (Save a copy in Drive)
# - Guardar una copia en Github (Save a Copy in Github)
# - Descargar (Download)

# %% [markdown]
# # Guardar otros archivos (Saving Other Files)
#
# ---
# ***
# Save a file by clicking the appropritate method:
# ***
# Guarde un archivo haciendo clic en el método apropiado:
# ***
# ---
# - Mount the Google Drive and save file to it
# - Download the File to local computer

# %%
! echo hola mis gatos > hola.txt

# %%
! cat hola.txt
# Out:
# hola mis gatos

# %%
# !ls
# Out:
# drive  hola.txt  sample_data

# %%
#mounting Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls
# Out:
# drive  hola.txt  sample_data

# %%
! ls drive/MyDrive

# %%
! mkdir drive/MyDrive/test

# %%
! cp hola.txt drive/MyDrive/test/hola.txt

# %%
# downloading files to local
from google.colab import files
files.download('hola.txt')

# %% [markdown]
# # Carga de otros archivos (Uploading Other Files)
#
# ---
# ***
# We upload files by:
# ***
# Subimos archivos por:
# ***
# ---
# - copiar desde Google Drive después del montaje (copying from the Google Drive after mounting)
# - cargar desde la computadora local (upload from local computer)
# - clonar un repositorio de github (clone a github repositiory)

# %% [markdown]
# ## Method 1: Google Drive

# %%
! cp  drive/MyDrive/test/hola.txt hola2.txt

# %%
! ls
# Out:
# drive  hola2.txt  hola.txt  sample_data

# %% [markdown]
# ## Method 2: Local Drive

# %%
#upload
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a05d2dc8-6fb8-4e37-ab34-5e1291e641b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a05d2dc8-6fb8-4e37-ab34-5e1291e641b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ic_logo.jpeg to ic_logo.jpeg
# {'ic_logo.jpeg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00d\x00d\x00\x00\xff\xec\x00\x11Ducky\x00\x01\x00\x04\x00\x00\x00F\x00\x00\xff\xee\x00&Adobe\x00d\xc0\x00\x00\x00\x01\x03\x00\x15\x04\x03\x06\n\r\x00\x001\x92\x00\x00W\xc5\x00\x00\x8cK\x00\x00\xde\xa3\xff\xdb\x00\x84\x00\x04\x03\x03\x03\x03\x03\x04\x03\x03\x04\x06\x04\x03\x04\x06\x07\x05\x04\x04\x05\x07\x08\x06\x06\x07\x06\x06\x08\n\x08\t\t\t\t\x08\n\n\x0c\x0c\x0c\x0c\x0c\n\x0c\x0c\r\r\x0c\x0c\x11\x11\x11\x11\x11\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x01\x04\x05\x05\x08\x07\x08\x0f\n\n\x0f\x14\x0e\x0e\x0e\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\xff\xc2\x00\x11\x08\x015 0!\x13\x061\x14@A"4\x152#3P$%5B\x166`D&\x11\x00\x01\x03\x01\x04\x07\x02\x0c\x02\x08\x06\x02\x02\x03\x00\x00\x01\x00\x02\x03\x11!1\x12\x04\x10AQaq"\x13\x812 \x91\xa1\xb1\xc1BRr#3\x14\x05\xd1b\x82\x92CScs$\x150\xf0\xe1\xa2\xb24\xf1D\xa3T\xd2\x84E\x12\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xb0\x13\x01\x00\x02\x02\x01\x04\x01\x04\x02\x03\x01\x01\x00\x00\x00\x00\x01\x00\x11!1A\x10Qaq\x81 \x91\xa1\xb10\xc1\xf0\xd1\xe1\xf1@\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00\x00\x01\x1a\xe3\xe8\xea~\x17A\xa6p&\x03c[\x9bt\xc64\x98\xa8n\x85\xa7g.\x9a\x94\xf4\xfc\x92X\xd0X\'UR\xa0\xf02%\x0e\xf6X\xe5\xca\xc1\xb0B"\xd2\x9a\x8a\xf6,\'"\xb5\x9cB\x9bq\x1e\x15\x8c\xd5\x15\xa7D\xb45B\x10\xcb\x95Q\xc0\xeb]\x07\x01H\xf3\x1b\x1e\xc1\xc7\xbeE\xd5\x8bT\x9bF\x8f\xcd\xd0\xda\x97\x15$\x1ai`\xa0\xf3\x1c\x14\x96PR\x81R\xd0K\x1d\xbcU%)\xa9\xb8\x84\xb4\xd0Y\'WS\xd0l\x1bD\xa1\xc2\xa3\xa4\xa0\x1b\x07\x91\x19\x92\xc5^\xc7\x87&J\x86\x9c\x07\x07\xe0`VsU\x172\x01H\x8a\xc5\x84z\x9e\x87\x99\xd6\xba\x0bM`\xd8x6n>\x8c{\xaf\x06\x1a\xf0\xb4\x8e>\xa8\xed<\x9aF\xd3\x9f1H\x89J\xb6\xe6\x0bO2-\xa8\x82\xb6\x8a\xbb\x8a\xa0\xa5=9h`\x1b\x14\xe1\xd5\xd2\xf2N\x84\xd9\xa9\xc0\x80\xa0\xd2\x12\x1cE\xf6u!\xb55X\x0f\x03\xe8\xac\xa5\xe1\xa1\x1c\x14ZV\xb3U\xf4\xaai8\xa5\xbak\x08u=\x05\x03l\xe2\x1f\x1a\x10\x90\xf0m\\{\xe3\xfd\x981I(\xfa?\xcd\xe9\xcet"\x8d`\xa6q\xa4\x04:\x9a\xad$g\xa3$\x04\x84\xd3.\xcaB,\xee\x9a\x94\xc0qWA\x02\xb0N\xa1\x8e\x8b\xa1&+\\\xc3Z\x9a\x9c\xb7\xa7&\x1c\xb4\x12\xa4M9\xa8\xac\tb\xb0\x9a\xad\xb9u5\'(+\xda\xb8\x97IAfl7l\xdb\x1b\x81]S\xd4%\x8a\x1b\x88l:\nC\x83\xd6\xb96\xc7:\xf0n\xe7\xc1\xf5\x9f\x97\xb67\xae\xb1\xc2\xc0\x16\x15t\x90(\x14\xa0i\x02]\x19Fd\xd9\xa5\xa2|\xbb\xbc\xea\xb6\x94\x91\xb8\x9a\x91\xe1X\x0e\x96\x92\xc1\xf4K\x8a\xde\xb96\xcd\xf7\xcf;\xe8\xce3\x94\x84\x94\xe1\x8aH\xea\xd8\xea,S\xa9\xd2^I\xd1\xca\x08(\xb9\x97IA\xa6v#\xa6P\xdb\x9c\x8a\xbb\x99\x92\xfa\x12Sl!X[\x8d\x18c\xa5\xfc\xba\x96\xb3N\x9ci\xb5\x97i\x1d\xf0u\xaaG\x13\xd0\xe2e\xe7y\x7fD%\x89\xa5E\xa4\x05te`\x91\x14k\x04\x96Ga.3V3P\xdaZ\x1e\t\xe3\xa6\xb9\xf2\x1dN\xce+^\xe4\xdb,\xe9\xc8C|\xe4\t\xb1\xbb$F\x9eU_I\xe4\xa6\x8e\xb6\xa5\xe0u;\xe8\xbd\xd3\x8b\xa2\xa7I\xa7\xb9\xbb\xce\xec\xa1\xc1\x01+\x82\xa8\xa9q\xa3\xe0\xf5J\x9a\xc0\xbbyu\x8e^\x8a\xcbU\xce\x036\x81-b\xf9\x15w;\x97\x97\xd9j\x14\x8a\xdf\x06\x05\x14t\xfbg\r\xaam$#\xa7+\x04\x13\xe5sd\x900\xed\xa0\xa6\x1c\x01\xe6\xdd8^eo\xb6\xfc\x90i8\n\x1b\xb0\xfe\x95\xf3z\xf2\xee\xacs^\x8cSi(\xe0\xdbr\xa1\xc0\x07\xd1-9\xc984\xb0\x83:\xde8\xba\xb3.\x8c\x9a\xa9>\xe6\xdb\xc1F\xe4\x1bh?\xe6\xd6\xdan[T\xb4\xaf\xa5\xe5\x1d|\xfa\x16:\x0f\xe99gV\x02{f\xe8<\x9c\x90\xfa;\xc9\xec!\xce\x80\xadT\xd3\x82\xcb\x1c\xd8\xafN0\xa9LD\xb6\x19g@;AV\x1aZ#\x11\xf49\xf7\xce-@m\xe3^\x8f\'\x01\xe0i\x12\x07\xc4x\x157\xf5\xd7\x93\xd9\x95\xf4e\x94\xf5aO\xa2P\xb8&\xd8\xe0(\x12\x85\'s\x0e\xeai\xa1\x90\xe7[\xb7\x1fH\x8e\xb9\rh\x ...

# %%
! ls
# Out:
# drive  hola2.txt  hola.txt  ic_logo.jpeg  sample_data

# %% [markdown]
# ## Method 3: Github Clone

# %%
! git clone https://github.com/ProfDoeg/Colegio_Invisible.git
# Out:
# Cloning into 'Colegio_Invisible'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 53 (delta 22), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (53/53), done.

# %%
! ls
# Out:
# Colegio_Invisible  drive  hola2.txt  hola.txt  ic_logo.jpeg  sample_data

# %%
! ls Colegio_Invisible
# Out:
# 01_cuaderno.ipynb  img	img.zip  README.md

# %%
! pip install cryptos

# %%
import cryptos
dog = cryptos.Doge()
btc = cryptos.Bitcoin()

# %%
#dog.__dir__()

# %%
#dog.__dict__

# %%
#btc.__dict__

# %%
dog.block_info(0)

# %%
i=0
while True:
  D1=dog.block_info(i)
  if len(D1['tx_hashes'])!=1:
    break
  i=i+1
D1,i

# %%
j=0
while True:
  B1=btc.block_info(j)
  if len(B1['tx_hashes'])!=1:
    break
  j=j+1
B1,j
